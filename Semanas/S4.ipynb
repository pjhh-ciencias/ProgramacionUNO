# %% [markdown]
# # Módulo Turtle

# %%
import turtle
t = turtle.Turtle()
#-----------------------------------------------------------------
#                Definir imagen del puntero
#-----------------------------------------------------------------
t.shape("turtle") #Tortuga
#t.shape("arrow") #flecha
#t.shape("circle") #Circulo
#t.shape("square") #Cuadrado
#t.shape("triangle") #Triangulo

#-----------------------------------------------------------------
#              Definiendo color de puntero y de trazo
#-----------------------------------------------------------------
turtle.color("black","blue")
turtle.exitonclick()

# %%
import turtle
t = turtle.Turtle()

#-----------------------------------------------------------------
#                Definir imagen del puntero
#-----------------------------------------------------------------
t.shape("turtle") #Tortuga
#t.shape("arrow") #flecha
#t.shape("circle") #Circulo
#t.shape("square") #Cuadrado
#t.shape("triangle") #Triangulo
turtle.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 import turtle
# ----> 2 t = turtle.Turtle()
#       4 #-----------------------------------------------------------------
#       5 #                Definir imagen del puntero
#       6 #-----------------------------------------------------------------
#       7 t.shape("turtle") #Tortuga
#
# File c:\Users\ima\AppData\Local\Programs\Python\Python311\Lib\turtle.py:3831, in Turtle.__init__(self, shape, undobuffersize, visible)
#    3829 if Turtle._screen is None:
#    3830     Turtle._screen = Screen()
# -> 3831 RawTurtle.__init__(self, Turtle._screen,
#    3832                    shape=shape,
#    3833                    undobuffersize=undobuffersize,
#    3834                    visible=visible)
#
# File c:\Users\ima\AppData\Local\Programs\Python\Python311\Lib\turtle.py:2558, in RawTurtle.__init__(self, canvas, shape, undobuffersize, visible)
#    2556 self._undobuffersize = undobuffersize
#    2557 self.undobuffer = Tbuffer(undobuffersize)
# -> 2558 self._update()
#
# File c:\Users\ima\AppData\Local\Programs\Python\Python311\Lib\turtle.py:2661, in RawTurtle._update(self)
#    2659     return
#    2660 elif screen._tracing == 1:
# -> 2661     self._update_data()
#    2662     self._drawturtle()
#    2663     screen._update()                  # TurtleScreenBase
#
# File c:\Users\ima\AppData\Local\Programs\Python\Python311\Lib\turtle.py:2647, in RawTurtle._update_data(self)
#    2646 def _update_data(self):
# -> 2647     self.screen._incrementudc()
#    2648     if self.screen._updatecounter != 0:
#    2649         return
#
# File c:\Users\ima\AppData\Local\Programs\Python\Python311\Lib\turtle.py:1293, in TurtleScreen._incrementudc(self)
#    1291 if not TurtleScreen._RUNNING:
#    1292     TurtleScreen._RUNNING = True
# -> 1293     raise Terminator
#    1294 if self._tracing > 0:
#    1295     self._updatecounter += 1
#
# Terminator:

# %%
import turtle
t = turtle.Turtle()
#-----------------------------------------------------------------
#              Definiendo color de puntero y de trazo
#-----------------------------------------------------------------
t.color("black","blue")

# %%
import turtle
t = turtle.Turtle()
#-----------------------------------------------------------------
#                           Movimientos
#-----------------------------------------------------------------
t.speed('slowest') # fastest,fast,normal,slow, slowest
t.forward(100) #Hacia adelante
t.backward(50) #Hacia atras
t.forward(50) #Hacia adelante

t.left(90) #Gira 90º en sentido contrario a las manecillas del reloj
t.forward(100) #Hacia adelante

t.right(90) #Gira 90º en el sentido de las manecillas del reloj
t.forward(100)

t.right(90)
t.forward(200)

t.right(90)
t.forward(200)

t.right(90)
t.forward(100)


#t.onclick(None)

# %%
import turtle
t = turtle.Turtle()
#-----------------------------------------------------------------
#                       Formas rellenas
#-----------------------------------------------------------------

t.clear()

t.begin_fill() #Instrucción introducida antes del código que dibuja la forma que se desea rellenar.

t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)

t.end_fill() #Instrucción agregada al final del código que dibuja la forma que se desea rellenar.

# t.pendown()
# t.begin_fill()


# #t.left(90)
# #t.forward(100)

t.turtle.exitonclick()

# %%
import turtle
t = turtle.Turtle()
#-----------------------------------------------------------------
#                    Comportamiento del lapiz
#-----------------------------------------------------------------

t.pendown() #Baja el lápiz – dibuja mientras se mueve.
t.penup() #Levanta el lápiz – no dibuja mientras se mueve.

# %% [markdown]
# ## Dibujando un cuadrado con Turtle

# %%
import turtle

t.shape("turtle") #Tortuga


t.color("black","blue")

t.speed('slowest') # fastest,fast,normal,slow, slowest

#t.clear()

#t.begin_fill() #Instrucción introducida antes del código que dibuja la forma que se desea rellenar.

# t.forward(100)
# t.right(90)
# t.forward(100)
# t.right(90)
# t.forward(100)
# t.right(90)
# t.forward(100)
# t.right(90)
# t.forward(100)
t.forward(100)
t.penup()
t.forward(100)
t.pendown()
t.forward(100)


#t.end_fill() #Instrucción agregada al final del código que dibuja la forma que se desea rellenar.

t.turtle.exitonclick()

# %% [markdown]
# ## Dibujando un pentagono

# %%
import turtle

t.shape("turtle") #Tortuga


t.color("blue")
t.speed('slowest')

t.begin_fill()
for i in range(5):
    t.forward(100)
    t.left(72)
t.end_fill()

t.exitonclick()

# %% [markdown]
# ### Pentágono relleno

# %%
import turtle

t.shape("turtle") #Tortuga

t.color("red","blue")
t.speed('normal')

for j in range(10):
    t.right(36)
    t.pendown()
    if j%2==0:
        t.begin_fill()
        for i in range(5):
                t.forward(100)
                t.left(72)
        t.penup()
        t.end_fill()
    else:
        for i in range(5):
                t.forward(100)
                t.left(72)


t.hideturtle()

t.exitonclick()

# %% [markdown]
# ## Polígono

# %%
import turtle

n=int(input('Ingresa un número entero mayor que 2: '))

while n <=2:
    print('El número debe ser entero mayor que 2.')
    n=int(input('Ingresa un número entero mayor que 2: '))

longitud=50
giro=360/n

t.shape("turtle")
t.color("black","blue")
t.speed("fastest")

for i in range(n):
    t.forward(longitud)
    t.left(giro)

# for j in range(72):
#     t.left(5)
#     for i in range(n):
#         t.forward(longitud)
#         t.left(giro)

t.hideturtle()
t.exitonclick()

# %% [markdown]
# https://www.pythonsandbox.com/turtle
