# %% [markdown]
# # <center> Quiz 5</center>

# %% [markdown]
# ## Instrucciones:
#
# * #### Para cada ejercicio debes enviar el notebook en formato `.ipynb` con las soluciones correspondientes a cada pregunta
#
# * ####  El notebook se deben nombrar de la siguiente manera:
#
# <center><font size=4><b>TuNombre_TuPrimerApellido_Q5</b></font></center>
#
#
# * #### Enviar el archivo al correo **pablo.jorge@aulavirtual.umar.mx**, en el asunto escribe **Quiz 5**.
#
# * #### ***No olvides primero descargar el notebook y luego adjuntar el archivo***, de otra forma el ejercicio no será tomado en cuenta.
#
# * #### **Importante:** Después de las 12:00 am por cada 5 minutos de retraso al enviar tus archivos se tendrá una penalización de 0.5 puntos menos sobre la calificación final del Quiz.

# %% [markdown]
# # Ejercicio 1 (5 puntos)
#
# #### Crea un programa en Python que dada una lista donde se tienen almacenados en tuplas, el nombre del tutor y de su tutorado. Como cada tutor puede tener más de un tutorado, hay tuplas que tienen como primer elemento al mismo tutor.
#
# ##### `lista_tutores_tutorados = [('Tutor1','Jorge'), ('Tutor2','Benito'), ('Tutor1','Mateo'), ('Tutor3','Maura'), ('Tutor1','Jesus'), ('Tutor4','Ximena')]`
#
# #### Despues de crear el diccionario e imprimirlo el resultado será algo similar a:
#
# ##### `{'Tutor1': ['Jorge', 'Mateo', 'Jesus'], 'Tutor4': ['Ximena'], 'Tutor3': ['Maura'], 'Tutor2': ['Benito']}`
#
# #### El resultado de imprimir a cada tutor  y sus correspondientes tutorados se debe ver como:
#
# <center>
# <img src="../Imagenes/tutores_tutorados.png" alt="", width="25%" height="auto">
#
# </center>

# %% [markdown]
# # Ejercicio 2  (5 puntos)
#
#
# #### En los siguientes conjuntos se almacenan los nombres de estudiantes que practican el determinado deporte:

# %%
futbol={'Jose','Ximena','Adrian','Mariana','Angel','Rosario','Jesus','Carolina'}
tenis={'Carolina','Manuel','Ximena', 'Paola','Adrian','Jorge','Mauricio','Rosario','Joel'}
atletismo={'Ximena','Angel','Mateo','Ximena','Paola','Janett','Cassandra','Mauricio'}

# %% [markdown]
# #### Utiliza instrucciones en Python para responder las siguientes preguntas:
#
# #### 1. ¿Qué estudiantes practican los tres deportes?
#
# #### 2. ¿Cuantos estudiantes practican los tres deportes?
#
# #### 3. ¿Qué estudiantes practican futbol y tenis pero no atletismo?
#
# #### 4. ¿Cuantos estudiantes practican futbol o tenis pero no atletismo?
#
# #### 5. ¿Qué estudiantes practican unicamente tenis?
#
# #### 6. Almacena en una lista el nombre de todos los estudiantes que practiquen alguno de los tres deportes.
#
# #### 7. Almacena en una lista el nombre de todos los estudiantes que practiquen uno y sólo uno de los tres deportes.
